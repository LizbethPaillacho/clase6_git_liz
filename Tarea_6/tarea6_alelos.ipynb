# %% [markdown]
# ### <center><h2> INGENIERÍA EN BIOTECNOLOGÍA</h2></center>
# # <center><h1 style="color:red">GBI6 - BIOINFORMÁTICA</h1></center>
#
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=400 height=300 />

# %% [markdown]
# ### Estudiante
# Lizbeth Paillacho
# ### Edad
# 24 años
# ### Semestre
# 6to
# ### Instrucciones
# * Crear un Júpiter Notebook tarea6_alelos.ipynb, cargar el módulo alelos y ejecutar las funciones hasta obtener la generación 100. Asegurarse que este cuaderno de jupyter tenga sus datos persoales, texto de explicación del ejercicio y de los resultados. Inserte al menos una imagen (logo de Ikiam). Asegurarse que el cuaderno tiene los resultados de ejecución de los bloques de código.
# * Crear un repositorio en GitHub de nombre tarea6 y guardar los dos archivos de la tarea. El repositorio debe tener una Readme con los detalles de la actividad.
# * Pegar el enlace del repositorio en la actividad T6_alelos de Moodle.

# %%
import Alelos

Fun = [Alelos.build_population(x, 0.55) for x in range(0, 100)]

NEW = [Alelos.reproduce_population(i) for i in Fun ]

Newg = [Alelos.compute_frequencies(i) for i in NEW]

print (Fun)
print (NEW)
print (Newg)
# Out:
# [[], [('A', 'a')], [('a', 'A'), ('a', 'A')], [('A', 'A'), ('A', 'A'), ('A', 'A')], [('A', 'a'), ('A', 'a'), ('A', 'A'), ('a', 'a')], [('A', 'A'), ('A', 'a'), ('a', 'A'), ('A', 'A'), ('a', 'a')], [('a', 'A'), ('a', 'a'), ('a', 'A'), ('A', 'A'), ('a', 'A'), ('a', 'a')], [('a', 'a'), ('a', 'A'), ('a', 'A'), ('A', 'A'), ('a', 'A'), ('a', 'a'), ('A', 'A')], [('A', 'a'), ('A', 'a'), ('A', 'A'), ('a', 'A'), ('A', 'A'), ('A', 'a'), ('A', 'a'), ('a', 'A')], [('A', 'A'), ('A', 'A'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('a', 'A'), ('A', 'a'), ('A', 'A'), ('a', 'A')], [('A', 'A'), ('a', 'A'), ('A', 'A'), ('a', 'A'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('A', 'A'), ('A', 'a'), ('A', 'a')], [('A', 'a'), ('A', 'A'), ('a', 'A'), ('A', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'A'), ('a', 'A')], [('A', 'A'), ('A', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('A', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a')], [('a', 'a'), ('a', 'A'), ('a', 'A
# ...
